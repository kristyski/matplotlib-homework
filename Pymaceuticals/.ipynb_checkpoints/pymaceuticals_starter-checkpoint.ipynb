# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_file = pd.merge(mouse_metadata, study_results, how="left", on=["Mouse ID", "Mouse ID"])

# Display the data table for preview
merged_file
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
mice_num = merged_file["Mouse ID"].nunique()
mice_num
# Out:
# 249

# %%
# All the data for the duplicate mouse ID.. 
finding_dups = merged_file[merged_file.duplicated(subset=["Mouse ID", "Timepoint"], keep=False)] #.count() gave me 10 rows
print(finding_dups)
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
renamed_merge_file_df = merged_file.rename(columns={"Mouse ID":"Mouse_ID"})
renamed_merge_file_df.head()

clean_df = renamed_merge_file_df.drop(renamed_merge_file_df[renamed_merge_file_df.Mouse_ID=="g989"].index)
clean_df
# Out:
#      Mouse_ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_mice_num = clean_df["Mouse_ID"].nunique()
clean_mice_num
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# This method produces everything in a single groupby function

cleaner_df = clean_df.rename(columns={"Tumor Volume (mm3)":"Tumor_Volume"})
# cleaner_df.head()

agg_stats = cleaner_df.groupby("Drug Regimen").Tumor_Volume.agg(["mean", "median", "var", "std", "sem"])
print(agg_stats)
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas.
count_timepoints = cleaner_df.groupby("Drug Regimen").Timepoint.count().sort_values()
print(count_timepoints)
# Out:
# Drug Regimen
# Propriva     148
# Ceftamin     178
# Infubinol    178
# Placebo      181
# Stelasyn     181
# Zoniferol    182
# Naftisol     186
# Ketapril     188
# Ramicane     228
# Capomulin    230
# Name: Timepoint, dtype: int64

# %%
panda_bar = count_timepoints.plot(kind="bar", x="Drug Regimen", y="count_timepoints", color="red", width=0.5, align="center",
                                  title="Number of Data Points per Drug Regimen")
plt.xlabel('Drug Regimen')
plt.ylabel('Data Points')
plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

matplotlib_df = pd.DataFrame({"Timepoints": count_timepoints})
matplotlib_df.sort_values("Timepoints", ascending=True).plot.bar(color='g',alpha=0.5, align="center")
plt.title("Number of Data Points per Drug Regimen")
plt.ylabel("Data Points")
# Out:
# Text(0, 0.5, 'Data Points')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
count_mice_sex = cleaner_df.Sex.value_counts()
panda_pie = count_mice_sex.plot(kind="pie", title="Female vs. Male Test Subjects", autopct='%1.1f%%')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = "Female", "Male"
plt.pie(count_mice_sex, autopct="%1.1f%%", startangle=90, labels=labels)

# Create axes which are equal so we have a perfect circle
plt.title("Female vs. Male Test Subjects")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
latest_time_df  = pd.DataFrame({"Timepoint":cleaner_df.groupby(["Mouse_ID"])["Timepoint"].max()}) #.last works here, too
# latest_time_df

# Merge above df with the original dataframe to get the tumor volume at the last timepoint
newly_merged_df = latest_time_df.merge(cleaner_df, on=["Mouse_ID", "Timepoint"], how="inner")
newly_merged_df
# Out:
#     Mouse_ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 243     z435         10     Propriva  Female          12          26
# 244     z578         45     Ramicane    Male          11          16
# 245     z581         45    Infubinol  Female          24          25
# 246     z795         45     Naftisol  Female          13          29
# 247     z969         45     Naftisol    Male           9          30
#
#      Tumor_Volume  Metastatic Sites
# 0       67.973419                 2
# 1       65.525743                 1
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# "Capomulin", "Ramicane", "Infubinol", "Ceftamin"
# Create empty list to fill with tumor vol data (for plotting)
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset

# %%
# interesting info
newly_merged_df.describe()
# Out:
#         Timepoint  Age_months  Weight (g)  Tumor_Volume  Metastatic Sites
# count  248.000000  248.000000  248.000000    248.000000        248.000000
# mean    32.903226   12.697581   26.116935     54.968606          1.681452
# std     15.495811    7.224093    3.704472     12.671479          1.328350
# min      0.000000    1.000000   15.000000     22.050126          0.000000
# 25%     20.000000    6.000000   25.000000     45.875867          1.000000
# 50%     45.000000   13.000000   27.000000     55.793278          1.000000
# 75%     45.000000   19.000000   29.000000     65.053624          3.000000
# max     45.000000   24.000000   30.000000     78.567014          4.000000

# %%
## there should be just be 100 subjects when only have the 4 drugs, trying to plot 
Capomulin = newly_merged_df.loc[newly_merged_df["Drug Regimen"]=="Capomulin"]
# Capomulin
Ramicane = newly_merged_df.loc[newly_merged_df["Drug Regimen"]=="Ramicane"]
# Ramicane
Infubinol = newly_merged_df.loc[newly_merged_df["Drug Regimen"]=="Infubinol"]
# Infubinol
Ceftamin = newly_merged_df.loc[newly_merged_df["Drug Regimen"]=="Ceftamin"]
# Ceftamin

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# well, this isn't correct, they're all stacked on top of one another
capbox = Capomulin.boxplot("Tumor_Volume", grid=False)
rambox = Ramicane.boxplot("Tumor_Volume", grid=False)
infbox = Infubinol.boxplot("Tumor_Volume", grid=False)
cefbox = Ceftamin.boxplot("Tumor_Volume", grid=False)

#but, this didn't work either
# plt.boxplot([Capomulin, Ramicane, Infubinol, Ceftamin])

plt.title("Boxplots by Drug Regimen")
plt.xlabel("Drugs")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
# Determine outliers using upper and lower bounds
cap_quartiles = Capomulin["Tumor_Volume"].quantile([.25, .5, .75])
cap_lowerq = round(cap_quartiles[0.25],0)
cap_upperq = round(cap_quartiles[0.75],0)
cap_iqr = cap_upperq-cap_lowerq
print(f"Capomulin:")
print(f"Lower quartile: {cap_lowerq}")
print(f"Upper quartile: {cap_upperq}")
print(f"Inner quartile range: {cap_iqr}")

cap_lower_bound = cap_lowerq - (1.5*cap_iqr)
cap_upper_bound = cap_upperq + (1.5*cap_iqr)
print(f"Values below {cap_lower_bound} could be outliers.")
print(f"Values above {cap_upper_bound} could be outliers.")
print("--------------------------------")

ram_quartiles = Ramicane["Tumor_Volume"].quantile([.25, .5, .75])
ram_lowerq = round(ram_quartiles[0.25],0)
ram_upperq = round(ram_quartiles[0.75],0)
ram_iqr = ram_upperq-ram_lowerq
print(f"Ramicane:")
print(f"Lower quartile: {ram_lowerq}")
print(f"Upper quartile: {ram_upperq}")
print(f"Inner quartile range: {ram_iqr}")

ram_lower_bound = ram_lowerq - (1.5*ram_iqr)
ram_upper_bound = ram_upperq + (1.5*ram_iqr)
print(f"Values below {ram_lower_bound} could be outliers.")
print(f"Values above {ram_upper_bound} could be outliers.")
print("--------------------------------")

inf_quartiles = Infubinol["Tumor_Volume"].quantile([.25, .5, .75])
inf_lowerq = round(inf_quartiles[0.25],0)
inf_upperq = round(inf_quartiles[0.75],0)
inf_iqr = inf_upperq-inf_lowerq
print(f"Infubinol:")
print(f"Lower quartile: {inf_lowerq}")
print(f"Upper quartile: {inf_upperq}")
print(f"Inner quartile range: {inf_iqr}")

inf_lower_bound = inf_lowerq - (1.5*inf_iqr)
inf_upper_bound = inf_upperq + (1.5*inf_iqr)
print(f"Values below {inf_lower_bound} could be outliers.")
print(f"Values above {inf_upper_bound} could be outliers.")
print("--------------------------------")

cef_quartiles = Ceftamin["Tumor_Volume"].quantile([.25, .5, .75])
cef_lowerq = round(cef_quartiles[0.25],0)
cef_upperq = round(cef_quartiles[0.75],0)
cef_iqr = cef_upperq-cef_lowerq
print(f"Ceftamin:")
print(f"Lower quartile: {cef_lowerq}")
print(f"Upper quartile: {cef_upperq}")
print(f"Inner quartile range: {cef_iqr}")

cef_lower_bound = cef_lowerq - (1.5*cef_iqr)
cef_upper_bound = cef_upperq + (1.5*cef_iqr)
print(f"Values below {cef_lower_bound} could be outliers.")
print(f"Values above {cef_upper_bound} could be outliers.")
# Out:
# Capomulin:
# Lower quartile: 32.0
# Upper quartile: 40.0
# Inner quartile range: 8.0
# Values below 20.0 could be outliers.
# Values above 52.0 could be outliers.
# --------------------------------
# Ramicane:
# Lower quartile: 32.0
# Upper quartile: 41.0
# Inner quartile range: 9.0
# Values below 18.5 could be outliers.
# Values above 54.5 could be outliers.
# --------------------------------
# Infubinol:
# Lower quartile: 54.0
# Upper quartile: 66.0
# Inner quartile range: 12.0
# Values below 36.0 could be outliers.
# Values above 84.0 could be outliers.
# --------------------------------
# Ceftamin:
# Lower quartile: 49.0
# Upper quartile: 64.0
# Inner quartile range: 15.0
# Values below 26.5 could be outliers.
# Values above 86.5 could be outliers.

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
randomcapomulin = newly_merged_df.loc[newly_merged_df["Drug Regimen"]=="Capomulin"]
randomcapomulin
# Out:
#     Mouse_ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 19      b128         45    Capomulin  Female           9          22
# 24      b742         45    Capomulin    Male           7          21
# 61      f966         20    Capomulin    Male          16          17
# 64      g288         45    Capomulin    Male           3          19
# 66      g316         45    Capomulin  Female          22          22
# 80      i557         45    Capomulin  Female           1          24
# 83      i738         45    Capomulin  Female          23          20
# 85      j119         45    Capomulin  Female           7          23
# 87      j246         35    Capomulin  Female          21          21
# 108     l509         45    Capomulin    Male          17          21
# 115     l897         45    Capomulin    Male          17          19
# 121     m601         45    Capomulin    Male          22          17
# 124     m957         45    Capomulin  Female           3          19
# ...

# %%
y793 = cleaner_df.loc[cleaner_df["Mouse_ID"]=="y793"]
# y793
plot = y793.plot.line(x="Timepoint", y="Tumor_Volume")
plt.title("Subject Number y793")
plt.ylabel("Tumor Volume (mm3)")
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
scatterdata = cleaner_df.loc[cleaner_df["Drug Regimen"]=="Capomulin"]
scatterdata2 = scatterdata.groupby(["Mouse_ID"]).mean()
scatterdata2

x_axis = scatterdata2["Weight (g)"]
y_axis = scatterdata2["Tumor_Volume"]

plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="grey", alpha=0.75)

plt.title("Drug Regimen: Capomulin")
plt.xlabel("Subject Weight (g)")
plt.ylabel("Tumor Volume (mm3)")

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
corr = round(sts.pearsonr(scatterdata2["Weight (g)"],scatterdata2["Tumor_Volume"])[0],2)
model = sts.linregress(scatterdata2["Weight (g)"],scatterdata2["Tumor_Volume"])

plt.scatter(scatterdata2["Weight (g)"],scatterdata2["Tumor_Volume"])
y_values = scatterdata2["Weight (g)"] * model[0] + model[1]

plt.plot(scatterdata2["Weight (g)"],y_values,color="red")
plt.title("Drug Regimen: Capomulin")
plt.xlabel("Subject Weight (g)")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')
